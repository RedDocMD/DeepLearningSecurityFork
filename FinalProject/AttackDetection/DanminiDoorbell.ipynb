# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install --upgrade tensorflow-gpu
# !pip3 install import-ipynb
# !pip3 install cuda-python

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
import pickle
import time
import sys

import import_ipynb
import AttackDetectionModel

import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import f1_score, confusion_matrix

from bayes_opt import BayesianOptimization

# %matplotlib inline
# Out:
# importing Jupyter notebook from AttackDetectionModel.ipynb

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction = 0.333)
sess = tf.compat.v1.Session(config = tf.compat.v1.ConfigProto(gpu_options = gpu_options))

# %% [markdown]
# # Data Pre-Processing

# %%
#number_features = 115
#number_features = 92
#number_features = 69
#number_features = 46
number_features = 23

# %%
# Get benign traffic 
df_dd_benign = AttackDetectionModel.get_files('../../nbaiot/Danmini_Doorbell', number_features)

# Get Bashlite traffic
df_dd_bashlite = AttackDetectionModel.get_files('../../nbaiot/Danmini_Doorbell/gafgyt', number_features)

# Get Mirai traffic
df_dd_mirai = AttackDetectionModel.get_files('../../nbaiot/Danmini_Doorbell/mirai', number_features)

# %%
# Normalize with the min-max scaler
scaler = MinMaxScaler()
df_dd_benign_norm = scaler.fit_transform(df_dd_benign)
df_dd_bashlite_norm = scaler.fit_transform(df_dd_bashlite)
df_dd_mirai_norm = scaler.fit_transform(df_dd_mirai)

# %% [markdown]
# # Sets

# %%
# Train set
len_benign_train = int(0.7 * len(df_dd_benign_norm))
X_train = df_dd_benign_norm[:len_benign_train]

# %%
# Test set
X_test_benign = df_dd_benign_norm[len_benign_train:]
X_test = np.concatenate([X_test_benign, df_dd_bashlite_norm, df_dd_mirai_norm])

Y_test = np.ones(len(X_test))
Y_test[:len(X_test_benign)] = 0

# %% [markdown]
# # Model

# %%
# Parameters
original_dim = X_train.shape[1]
input_shape = (original_dim,)
intermediate_dim = int(original_dim / 2)
latent_dim = int(original_dim / 3)

# Initial values
epochs = 5
learning_rate = 0.0001
batch_size = 82
anomaly_threshold = 0.042

# Dictionary
dict_params = { 'learning_rate': learning_rate, 'batch_size': round(batch_size), 'epochs': round(epochs)}
pbounds = { 'learning_rate': (0.000001, 0.001), 'batch_size': (10, 100), 'epochs': (50, 500)}

# %%
# KL Loss function
def vae_loss(x, x_decoded_mean):
    # Compute the average MSE error, then scale it up (sum on all axes)
    
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean))
    
    # Compute the KL loss
    
    kl_loss = - 0.5 * K.sum(1 + z_var - K.square(z_mean) - K.square(K.exp(z_var)), axis=-1)
    
    # Return the average loss over all 
    
    total_loss = K.mean(reconstruction_loss + kl_loss) # Total_loss = reconstruction_loss + kl_loss 
    return total_loss

# (1) Reconstruction Loss - Forces the encoder to generate latent features that minimize the reconstruction error, or else is
# penalized
# (2) KL Loss - Forces the distribution generated by the encoder to be similar to the prior probability of the input vector, 
# pushing latent feature space to normality

# %%
# Encoder
inputs, encoder, z_var, z_mean = AttackDetectionModel.vae_encoder(input_shape, 
                                                                  intermediate_dim, 
                                                                  latent_dim, 
                                                                  AttackDetectionModel.reparametrization)
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 23)]         0           []
#
#  dense (Dense)                  (None, 11)           264         ['encoder_input[0][0]']
#
#  z_mean (Dense)                 (None, 7)            84          ['dense[0][0]']
#
#  z_var (Dense)                  (None, 7)            84          ['dense[0][0]']
#
#  z (Lambda)                     (None, 7)            0           ['z_mean[0][0]',
#                                                                   'z_var[0][0]']
#
# ==================================================================================================
# Total params: 432
# Trainable params: 432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder
decoder = AttackDetectionModel.vae_decoder(intermediate_dim, latent_dim, original_dim)
outputs = decoder(encoder(inputs))
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 7)]               0
#
#  dense_1 (Dense)             (None, 11)                88
#
#  dense_2 (Dense)             (None, 23)                276
#
# =================================================================
# Total params: 364
# Trainable params: 364
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter Optimization

# %%
def maximize_training(X_train = X_train, 
                      X_test = X_test, 
                      Y_test = Y_test, 
                      inputs = inputs, 
                      outputs = outputs, 
                      vae_loss = vae_loss,
                      learning_rate = learning_rate,
                      batch_size = batch_size,
                      epochs = epochs,
                      anomaly_threshold = anomaly_threshold):    
    
    # Create model
    opt_adam = optimizers.Adam(learning_rate = dict_params['learning_rate'], clipvalue = 0.5)
    model = Model(inputs, outputs, name = 'vae_mlp')
    model.compile(optimizer = opt_adam, loss = vae_loss)

    # Train
    history = model.fit(X_train, 
                        X_train, 
                        shuffle = True, 
                        verbose = 0,
                        epochs = dict_params['epochs'], 
                        batch_size = dict_params['batch_size'])
    
    # Maximize the f1-score
    X_pred_opt = model.predict(X_test)
    error_vector_opt = AttackDetectionModel.get_error_term(X_pred_opt, X_test, _rmse = False)
    Y_pred_opt = (error_vector_opt > anomaly_threshold)
    f1 = f1_score(Y_test, Y_pred_opt)
    
    return f1

# %%
'''
# Apply Bayesian optimization to choose the best hyperparameters

opt = BayesianOptimization(f = maximize_training,
                           pbounds = pbounds,
                           verbose = 2, 
                           random_state = 1)

opt_start = time.time()

opt.maximize(init_points = 5, n_iter = 5)

opt_end = time.time()
opt_time = opt_end - opt_start
print("Optimization time:", opt_time)

learning_rate = opt.max['params']['learning_rate']
epochs = round(opt.max['params']['epochs'])
batch_size = round(opt.max['params']['batch_size'])
'''
# Out:
# '\n# Apply Bayesian optimization to choose the best hyperparameters\n\nopt = BayesianOptimization(f = maximize_training,\n                           pbounds = pbounds,\n                           verbose = 2, \n                           random_state = 1)\n\nopt_start = time.time()\n\nopt.maximize(init_points = 5, n_iter = 5)\n\nopt_end = time.time()\nopt_time = opt_end - opt_start\nprint("Optimization time:", opt_time)\n\nlearning_rate = opt.max[\'params\'][\'learning_rate\']\nepochs = round(opt.max[\'params\'][\'epochs\'])\nbatch_size = round(opt.max[\'params\'][\'batch_size\'])\n'

# %% [markdown]
# # Predict Attacks

# %%
# Training step with the best hyperparameters
learning_rate = 0.0005176628103160156
epochs = 152
batch_size = 99
opt_time = 500.309711933136
anomaly_threshold = 0.02

# %%
for i in range(1):
    print("Iteration " + str(i))
    
    # Train
    vae_model, train_time = AttackDetectionModel.train(X_train, inputs, outputs, vae_loss, learning_rate, epochs, batch_size)
   
    # Set the optimized anomaly threshold
    #anomaly_threshold = AttackDetectionModel.get_anomaly_threshold(X_train, vae_model)
    
    # Test
    X_pred, test_time = AttackDetectionModel.test(X_test, vae_model)
    Y_test, Y_pred = AttackDetectionModel.get_prediction(Y_test, X_pred, X_test, anomaly_threshold, vae_model)

    # Metrics
    acc, f1, pre, rec = AttackDetectionModel.get_scores(Y_test, Y_pred)
    
    # Print results
    AttackDetectionModel.print_results(number_features,
                                       learning_rate,
                                       epochs,
                                       batch_size,
                                       anomaly_threshold,
                                       X_train,
                                       X_test,
                                       opt_time,
                                       train_time,
                                       test_time,
                                       acc,
                                       f1,
                                       pre,
                                       rec,
                                       Y_test,
                                       Y_pred,
                                       "Results/danmini_doorbell.txt")
    
    print("")
# Out:
# Iteration 0
# Train on 34683 samples
# Epoch 1/152
# 34683/34683 [==============================] - 1s 19us/sample - loss: 242.1338
# Epoch 2/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 28.5527
# Epoch 3/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 13.5450
# Epoch 4/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 9.7795
# Epoch 5/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 7.2997
# Epoch 6/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 6.3300
# Epoch 7/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 5.7041
# Epoch 8/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 5.2508
# Epoch 9/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 4.9266
# Epoch 10/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 4.5385
# Epoch 11/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 3.9228
# Epoch 12/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 3.4189
# Epoch 13/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 3.2470
# Epoch 14/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 3.1252
# Epoch 15/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 3.0734
# Epoch 16/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 3.0189
# Epoch 17/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.9554
# Epoch 18/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.9281
# Epoch 19/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.9065
# Epoch 20/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.8678
# Epoch 21/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.8417
# Epoch 22/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.8249
# Epoch 23/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.8062
# Epoch 24/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.7809
# Epoch 25/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.7547
# Epoch 26/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.7518
# Epoch 27/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.7291
# Epoch 28/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.7093
# Epoch 29/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.7040
# Epoch 30/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.6958
# Epoch 31/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.6825
# Epoch 32/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.6731
# Epoch 33/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.6650
# Epoch 34/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.6444
# Epoch 35/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.6292
# Epoch 36/152
# 34683/34683 [==============================] - 0s 11us/sample - loss: 2.6192
# Epoch 37/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.6278
# Epoch 38/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.6137
# Epoch 39/152
# 34683/34683 [==============================] - 1s 14us/sample - loss: 2.6068
# Epoch 40/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.6001
# Epoch 41/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5968
# Epoch 42/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5775
# Epoch 43/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5744
# Epoch 44/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5718
# Epoch 45/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5533
# Epoch 46/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5516
# Epoch 47/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5275
# Epoch 48/152
# 34683/34683 [==============================] - 0s 11us/sample - loss: 2.5405
# Epoch 49/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.5350
# Epoch 50/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.5168
# Epoch 51/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.5186
# Epoch 52/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5117
# Epoch 53/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.5057
# Epoch 54/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4973
# Epoch 55/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.5048
# Epoch 56/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.4892
# Epoch 57/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4832
# Epoch 58/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4814
# Epoch 59/152
# 34683/34683 [==============================] - 0s 11us/sample - loss: 2.4764
# Epoch 60/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4701
# Epoch 61/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4821
# Epoch 62/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4522
# Epoch 63/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4555
# Epoch 64/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4573
# Epoch 65/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4624
# Epoch 66/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.4596
# Epoch 67/152
# 34683/34683 [==============================] - 1s 14us/sample - loss: 2.4507
# Epoch 68/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4531
# Epoch 69/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.4420
# Epoch 70/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4416
# Epoch 71/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4304
# Epoch 72/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4244
# Epoch 73/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4291
# Epoch 74/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4115
# Epoch 75/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4044
# Epoch 76/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4295
# Epoch 77/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4045
# Epoch 78/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.4019
# Epoch 79/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3955
# Epoch 80/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3994
# Epoch 81/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3877
# Epoch 82/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3864
# Epoch 83/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3787
# Epoch 84/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3702
# Epoch 85/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3642
# Epoch 86/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3616
# Epoch 87/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3601
# Epoch 88/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3502
# Epoch 89/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.3566
# Epoch 90/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.3458
# Epoch 91/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3433
# Epoch 92/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3378
# Epoch 93/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3274
# Epoch 94/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.3175
# Epoch 95/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.3088
# Epoch 96/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3220
# Epoch 97/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3121
# Epoch 98/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3009
# Epoch 99/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.3011
# Epoch 100/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2937
# Epoch 101/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.2745
# Epoch 102/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2761
# Epoch 103/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2608
# Epoch 104/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.2810
# Epoch 105/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2742
# Epoch 106/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2802
# Epoch 107/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2602
# Epoch 108/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.2369
# Epoch 109/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2332
# Epoch 110/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2334
# Epoch 111/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2347
# Epoch 112/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2364
# Epoch 113/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.2320
# Epoch 114/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.2377
# Epoch 115/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.2322
# Epoch 116/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.2251
# Epoch 117/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.2260
# Epoch 118/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2210
# Epoch 119/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2297
# Epoch 120/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2128
# Epoch 121/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.2059
# Epoch 122/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2109
# Epoch 123/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.2135
# Epoch 124/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1991
# Epoch 125/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.1992
# Epoch 126/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1952
# Epoch 127/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2027
# Epoch 128/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.1992
# Epoch 129/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1964
# Epoch 130/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.1993
# Epoch 131/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.2008
# Epoch 132/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1918
# Epoch 133/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1845
# Epoch 134/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.1930
# Epoch 135/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1801
# Epoch 136/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.1821
# Epoch 137/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.1765
# Epoch 138/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1842
# Epoch 139/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.1786
# Epoch 140/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1855
# Epoch 141/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.1747
# Epoch 142/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1903
# Epoch 143/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.1796
# Epoch 144/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.1794
# Epoch 145/152
# 34683/34683 [==============================] - 0s 12us/sample - loss: 2.1798
# Epoch 146/152
# 34683/34683 [==============================] - 0s 13us/sample - loss: 2.1888
# Epoch 147/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.1720
# Epoch 148/152
# 34683/34683 [==============================] - 1s 15us/sample - loss: 2.1768
# Epoch 149/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.1707
# Epoch 150/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.1760
# Epoch 151/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.1703
# Epoch 152/152
# 34683/34683 [==============================] - 0s 14us/sample - loss: 2.1871
# Training time: 68.72921943664551
# /usr/lib/python3.10/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Testing time: 10.12479281425476

# %% [markdown]
# # Metrics

# %%
# Examinig the latent space generated by the encoder
X_encoded = encoder.predict(X_test)

pca = PCA(n_components=2)
X_analysis = pca.fit_transform(X_encoded)
# Out:
# /usr/lib/python3.10/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_pred)
plt.grid()
plt.savefig("Results/PCA/DD_" + str(number_features))
plt.show()

# Orange ones are anomalies

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = X_analysis[:, 0], y = X_analysis[:, 1], s = 20, hue = Y_test)
plt.grid()
plt.savefig("Results/PCA Groundtruth/DD_" + str(number_features))
plt.show()

# Ground truth

# %%
conf_matrix = confusion_matrix(Y_test, Y_pred)

fig, ax = plt.subplots(figsize = (5, 5))
ax.matshow(conf_matrix, cmap = plt.cm.Blues, alpha = 0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x = j, y = i,s = conf_matrix[i, j], va = 'center', ha = 'center', size = 'large')
 
plt.xlabel('Predictions', fontsize=12)
plt.ylabel('Actuals', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.savefig("Results/Confusion Matrix/DD_" + str(number_features))
plt.show()
